# %%
import numpy as np

# %%
print('hello')
# Out:
# hello

# %%
1 + 1
# Out:
# 2

# %%
data = [44,8,32,45,37,42,47,26,31,11]

print(np.mean(data))
print(np.median(data))
print(np.std(data))
print(np.var(data))
# Out:
# 32.3
# 34.5
# 13.1
# 171.61

# %%
nested = [
    [1,2,3],
    [4,5,6]
]
print(nested[0][0])
# Out:
# 1

# %%
ndarray = np.array([
    [1,2,3],
    [4,5,6]
])
print(ndarray[0,0])
# Out:
# 1

# %%
nested_list = [
    [20,40],
    [60,80],
    [100,120]
]
print(nested_list[1][0])

nd_array = np.array([
    [20,40],
    [60,80],
    [100,120]
])
print(nd_array[1,0])
# Out:
# 60
# 60

# %%
print(nd_array + 1)
# Out:
# [[ 21  41]
#  [ 61  81]
#  [101 121]]

# %%
#####Matplot lib notes

# %%
import numpy as np
import matplotlib.pyplot as plt
arr = np.array ([[1,2], [3,4]])
print(np.shape(arr)) 
print(np.man(arr))
print(np.median(arr))
print(arr * 3)
print(arr [:, 1])
# Out:
# (2, 2)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 5
#       3 arr = np.array ([[1,2], [3,4]])
#       4 print(np.shape(arr))
# ----> 5 print(np.man(arr))
#       6 print(np.median(arr))
#       7 print(arr * 3)
#
# File /opt/anaconda3/lib/python3.13/site-packages/numpy/__init__.py:414, in __getattr__(attr)
#     411     import numpy.char as char
#     412     return char.chararray
# --> 414 raise AttributeError("module {!r} has no attribute "
#     415                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'man'

# %%
fig, axes = plt.subplots(2,1, figsize (4,7))

axes[0].scatter(x, y1, color = "red")
axes[0].set_title("Sine Wave", color = "red")

axes[1].scatter(x,y2,color = "purple")
axes[1].set_title("Cosine Wave", color = "purple")

plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 fig, axes = plt.subplots(2,1, figsize (4,7))
#       3 axes[0].scatter(x, y1, color = "red")
#       4 axes[0].set_title("Sine Wave", color = "red")
#
# NameError: name 'figsize' is not defined

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace( 0, 2 * np.pi, 200)

fig, axes = plt.subplots(1, 2, figsize = (15, 4))

axes[0].plot(x, np.sin(x))
axes[0].set_title ("sin(x)")
axes[0].set_xlabel("x-axis")
axes[0].set_ylabel("y-axis")

axes[1].plot(x, np.sin(2*x))
axes[1].set_title("sin(2x)")
axes[1].set_xlabel("x-axis")
axes[1].set_ylabel("y-axis")

#axes[2].plot(x, np.sin(3*x))
#axes[2].set_title("sin(3x)")
#axes[2].set_xlabel("x-axis")
#axes[2].set_ylabel("y-axis")

plt.show()

# %%
def plot_function(func_name):
    func = getattr(np, func_name)
    x = np.linspace(-10, 10,400)
    y = func(x)

    plt.plot(x, y)
    plt.title(f"y = {func_name}(x)")
    plt.xlabel("x")
    plt.ylabel(f"{func_name}(x)")
    plt.show()
    
plot_function("sin")
