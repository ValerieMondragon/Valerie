# %%
import numpy as np

# %%
print('hello')
# Out:
# hello

# %%
1 + 1
# Out:
# 2

# %%
data = [44,8,32,45,37,42,47,26,31,11]

print(np.mean(data))
print(np.median(data))
print(np.std(data))
print(np.var(data))
# Out:
# 32.3
# 34.5
# 13.1
# 171.61

# %%
nested = [
    [1,2,3],
    [4,5,6]
]
print(nested[0][0])
# Out:
# 1

# %%
ndarray = np.array([
    [1,2,3],
    [4,5,6]
])
print(ndarray[0,0])
# Out:
# 1

# %%
nested_list = [
    [20,40],
    [60,80],
    [100,120]
]
print(nested_list[1][0])

nd_array = np.array([
    [20,40],
    [60,80],
    [100,120]
])
print(nd_array[1,0])
# Out:
# 60
# 60

# %%
print(nd_array + 1)
# Out:
# [[ 21  41]
#  [ 61  81]
#  [101 121]]
